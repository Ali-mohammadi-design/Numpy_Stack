# %% [markdown]
# <a href="https://colab.research.google.com/github/Ali-mohammadi-design/Numpy_Stack/blob/main/Histogram_and_pictures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.random.rand(10000)

# %%
plt.hist(x,bins=50)
# Out:
# (array([221., 220., 201., 197., 211., 204., 197., 199., 222., 202., 201.,
#         198., 208., 203., 172., 170., 194., 213., 195., 178., 190., 216.,
#         196., 165., 214., 205., 223., 215., 208., 204., 192., 165., 233.,
#         184., 216., 200., 205., 193., 193., 218., 172., 188., 223., 172.,
#         216., 190., 217., 191., 186., 204.]),
#  array([8.98785525e-05, 2.00872986e-02, 4.00847186e-02, 6.00821386e-02,
#         8.00795586e-02, 1.00076979e-01, 1.20074399e-01, 1.40071819e-01,
#         1.60069239e-01, 1.80066659e-01, 2.00064079e-01, 2.20061499e-01,
#         2.40058919e-01, 2.60056339e-01, 2.80053759e-01, 3.00051179e-01,
#         3.20048599e-01, 3.40046019e-01, 3.60043439e-01, 3.80040859e-01,
#         4.00038279e-01, 4.20035699e-01, 4.40033119e-01, 4.60030539e-01,
#         4.80027959e-01, 5.00025379e-01, 5.20022799e-01, 5.40020219e-01,
#         5.60017639e-01, 5.80015059e-01, 6.00012479e-01, 6.20009899e-01,
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2c3c0dc2-4b42-48c8-9961-21479ab17106" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2c3c0dc2-4b42-48c8-9961-21479ab17106">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from PIL import Image

# %%
image = Image.open("my_Photo.jpg")

# %%
arr_img=np.array(image)

# %%
arr_img.shape
# Out:
# (472, 354, 3)

# %%
#plt.imshow(arr_img)

# %%
arr=arr_img.mean(axis=2)

# %% [markdown]
# We are taking a mean across three matrix that determines the colors.
# Image Array Shape
# An RGB image in NumPy is usually structured like this:
#
# python
# Copy
# Edit
# arr_img.shape  ➞  (height, width, 3)
# Axis 0 → rows (height)
#
# Axis 1 → columns (width)
#
# Axis 2 → color channels (Red, Green, Blue)
#
# So, axis indices are:
#
# Axis	Meaning	Example Dimension
# 0	Height	480 pixels
# 1	Width	640 pixels
# 2	Color channels	3 (RGB)

# %%
arr.shape
# Out:
# (472, 354)

# %%
#plt.imshow(arr)

# %%
#plt.imshow(arr, cmap='gray')

# %%
x1=np.random.uniform(-2,2, 10000)
x2=np.random.uniform(-2,2,10000)

# %%
c=x1*x2

# %%
plt.scatter(x1, x2, c=c)
